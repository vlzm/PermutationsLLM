# %% [markdown]
# # LLM-based Permutation Solver - Testing Notebook
#
# ## Purpose
# - Generate sorting algorithms via LLM APIs (OpenAI, Gemini, Claude)
# - Sort permutations using only 3 moves: **L** (left shift), **R** (right shift), **X** (swap first two)
# - Test and verify generated solutions
#
# ## Structure
# 1. **Basic Operations** — Demo of L, R, X moves
# 2. **Random Permutations** — Generate test data
# 3. **Custom Prompts** — Editable system/main prompts
# 4. **LLM Providers** — Setup for OpenAI, Claude, Gemini
# 5. **Solver Pipeline** — Full generation & testing workflow
# 6. **Manual Execution** — Run and verify custom code
# 7. **Provider Comparison** — Compare results across LLMs
# 8. **Save Code** — Export generated algorithms

# %%
# Import required modules
import numpy as np
import json
from main import (
    PermutationSolver,
    PermutationConfig,
    get_llm_client,
    generate_random_permutation,
    apply_moves,
    is_trivial,
    verify_solution,
    get_system_prompt,
    get_main_prompt,
    extract_python_code,
    OPTIMIZE_PROMPT_TEMPLATE
)

# %% [markdown]
# ## 1. Basic Permutation Operations
#
# Let's first understand the basic operations (L, R, X).

# %%
from main import apply_L, apply_R, apply_X

# Example array
arr = np.array([0, 1, 2, 3])
print(f"Original: {arr}")
print(f"After L (left shift): {apply_L(arr)}")
print(f"After R (right shift): {apply_R(arr)}")
print(f"After X (swap first two): {apply_X(arr)}")
# Out:
# Original: [0 1 2 3]
# After L (left shift): [1 2 3 0]
# After R (right shift): [3 0 1 2]
# After X (swap first two): [1 0 2 3]

# %%
# Apply a sequence of moves
arr = np.array([1, 2, 3, 0])
moves = ['L', 'L', 'X', 'R']

print(f"Original: {arr}")
result = apply_moves(arr, moves)
print(f"After moves {moves}: {result}")
print(f"Is trivial: {is_trivial(result)}")
# Out:
# Original: [1 2 3 0]
# After moves ['L', 'L', 'X', 'R']: [2 0 3 1]
# Is trivial: False

# %% [markdown]
# ## 2. Generate Random Permutations

# %%
# Generate random permutations of different lengths
for n in [4, 6, 8]:
    perm = generate_random_permutation(n)
    print(f"Length {n}: {perm}")
# Out:
# Length 4: [1 2 0 3]
# Length 6: [2 3 0 5 4 1]
# Length 8: [5 2 0 4 7 6 1 3]

# %% [markdown]
# ## 3. Prompts Configuration
#
# ### 3.1 Custom Prompts (Editable)
#
# You can customize the prompts below and use them with the solver. Edit these cells and set `USE_CUSTOM_PROMPTS = True` in section 5 to use your custom prompts.

# %%
# Custom System Prompt - edit as needed
CUSTOM_SYSTEM_PROMPT = """You are an expert algorithm designer specializing in combinatorial puzzles and permutation theory.
Your task is to create efficient, constructive algorithms that solve permutation problems using only allowed moves.
You must provide working Python code that is self-contained and can be executed directly.
Always follow the constraints specified in the task and provide polynomial-time solutions."""

# %%
CUSTOM_MAIN_PROMPT = """Task: Implement a constructive sorting algorithm that sorts a given vector using ONLY allowed moves (L, R, X).

Input: A vector a of length n (0-indexed) containing distinct integers from 0 to n-1.

Allowed moves:
L: Left cyclic shift — shifts all elements one position to the left, with the first element moving to the end. Example: [0,1,2,3] -> [1,2,3,0].
R: Right cyclic shift — shifts all elements one position to the right, with the last element moving to the beginning. Example: [0,1,2,3] -> [3,0,1,2].
X: Transposition of the first two elements — swaps the elements at positions 0 and 1. Example: [0,1,2,3] -> [1,0,2,3].

CRITICAL CONSTRAINTS:
1. NO BFS, DFS, or any graph search algorithms are allowed
2. The algorithm must run in POLYNOMIAL TIME (O(n^k) for some constant k)
3. No exponential-time algorithms (like brute force search through permutations)
4. Must use a constructive, iterative approach that builds the solution step by step
5. No storing or exploring multiple states simultaneously

Strict operational constraints:
- No other operations, slicing, built-in sorting functions, or creating new arrays are allowed (except for a copy to simulate sorting)
- All moves must be appended to the moves list immediately after performing them (as strings: 'L', 'R', or 'X')
- Applying the sequence of moves sequentially to a copy of the input vector must yield a fully sorted ascending array [0, 1, 2, ..., n-1]
- Moves can be used multiple times as needed
- The algorithm must continue applying moves until the array is fully sorted

ALGORITHMIC REQUIREMENTS:
- Use a constructive approach: develop a strategy that systematically brings elements to their correct positions
- Think in terms of bringing the smallest unsorted element to the front, then "locking" it in place
- Consider how L and R can help position elements for X swaps
- The solution should work for any n and have predictable, polynomial-time complexity

Expected approach types (choose one):
1. Adaptation of bubble sort/insertion sort using available moves
2. Strategy of bringing smallest element to front, then second smallest, etc.
3. Any other polynomial-time constructive approach

Implementation requirements:
- Implement a function solve(vector) that returns a tuple (moves, sorted_array):
    - moves: list of strings representing all moves performed (e.g., ['L', 'X', 'R', ...])
    - sorted_array: the final sorted array after applying all moves (as a list)
- Include CLI interface:
    - When script is executed directly, accept vector as command-line argument (parse sys.argv[1] as JSON)
    - Use {default_vector} as fallback if no arg is given
    - Output should be JSON object with keys "moves" and "sorted_array"
- Include minimal example in main block for quick testing
- Code must be fully self-contained and executable without external dependencies (only sys, json allowed)
- JSON output must always be structured and parseable for automated testing

Example usage:
    python solve_module.py "[3,1,2,0,4]"

Example output (for illustration):
{{
    "moves": ["X", "L", "R", "X"],
    "sorted_array": [0,1,2,3,4]
}}

IMPORTANT: Focus on developing a polynomial-time constructive algorithm, NOT graph search.
Provide ONLY the Python code, no explanations before or after."""

# %% [markdown]
# ## 4. Using Different LLM Providers
#
# Set your API keys as environment variables:
# - `OPENAI_API_KEY` for OpenAI
# - `GOOGLE_API_KEY` for Gemini
# - `ANTHROPIC_API_KEY` for Claude

# %%
# Set API keys (uncomment and fill in your keys)
import os

if os.getenv("OPENAI_API_KEY") is None:
    raise RuntimeError(
        "OPENAI_API_KEY is not set. "
        "Add it via Kaggle Secrets or environment variables."
    )
else:
    os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
model_name = 'gpt-5.2'

# %% [markdown]
# ### 4.1 OpenAI Example

# %%
# Create OpenAI client
try:
    openai_client = get_llm_client('openai', model=model_name)
    print(f"Created client: {openai_client.name}")
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Created client: OpenAI (gpt-5.2)

# %% [markdown]
# ### 4.2 ANTHROPIC Example

# %%
if os.getenv("ANTHROPIC_API_KEY") is None:
    raise RuntimeError(
        "ANTHROPIC_API_KEY is not set. "
        "Add it via Kaggle Secrets or environment variables."
    )
else:
    os.environ['ANTHROPIC_API_KEY'] = os.getenv("ANTHROPIC_API_KEY")
try:
    claude_client = get_llm_client('claude', model='claude-opus-4-5-20251101')
    print(f"Created client: {claude_client.name}")
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Created client: Claude (claude-opus-4-5-20251101)

# %% [markdown]
# ## 5. Full Solver Pipeline
#
# Here's how to use the full solver pipeline.

# %%
# Choose your provider (change as needed)
from ast import mod


PROVIDER = 'claude'  # 'openai', or 'claude'
model_name = 'claude-opus-4-5-20251101'

# Set USE_CUSTOM_PROMPTS = True to use your custom prompts from section 3.1
USE_CUSTOM_PROMPTS = True

try:
    client = get_llm_client(PROVIDER, model=model_name)
    
    if USE_CUSTOM_PROMPTS:
        # Use custom prompts defined in section 3.1
        config = PermutationConfig(
            length=4,
            system_prompt=CUSTOM_SYSTEM_PROMPT,
            main_prompt_template=CUSTOM_MAIN_PROMPT
        )
        print("Using CUSTOM prompts")
    else:
        # Use default prompts from main.py
        config = PermutationConfig(length=4)
        print("Using DEFAULT prompts")
    
    solver = PermutationSolver(client, config)
    print(f"Solver created with {client.name}")
except Exception as e:
    print(f"Error creating solver: {e}")
    solver = None
# Out:
# Using CUSTOM prompts
# Solver created with Claude (claude-opus-4-5-20251101)

# %%
# Generate the algorithm (this calls the LLM)
if solver:
    code = solver.generate_algorithm(4)
    print("Generated code:")
    print("=" * 60)
    print(code)
    print("=" * 60)

    # Optimize the algorithm via a second LLM call
    # Asks the LLM to improve complexity to O(n^2), specifically <= 0.5*n^2 + O(n)
    optimized_code = solver.optimize_algorithm()
    print("\nOptimized code:")
    print("=" * 60)
    print(optimized_code)
    print("=" * 60)
    print(f"\nOriginal code length: {len(solver.original_code)} chars")
    print(f"Optimized code length: {len(optimized_code)} chars")
# Out:
# Generating algorithm using Claude (claude-opus-4-5-20251101)...
# Generated code:
# ============================================================
# import sys
# import json
#
# def solve(vector):
#     """
#     Sorts a vector using only L, R, X moves in polynomial time.
#
#     Strategy: Selection sort style - for each position i from 0 to n-1,
#     we bring the element that should be at position i (which is value i)
#     to the front using rotations, then rotate the sorted prefix back.
#
#     Key insight: We can think of the array as a cycle. To place element k
#     at position k, we:
#     1. Rotate until element k is at position 0 or 1
#     2. Use X if needed to get it to position 0
#     3. Rotate right k times to put it at position k
#     """
#     n = len(vector)
#     if n <= 1:
#         return ([], list(vector))
#
#     # Work on a copy
#     a = list(vector)
#     moves = []
#
#     def do_L():
#         """Left cyclic shift"""
#         temp = a[0]
#         for i in range(n - 1):
#             a[i] = a[i + 1]
#         a[n - 1] = temp
#         moves.append('L')
#
#     def do_R():
#         """Right cyclic shift"""
#         temp = a[n - 1]
#         for i in range(n - 1, 0, -1):
#             a[i] = a[i - 1]
#         a[0] = temp
#         moves.append('R')
#
#     def do_X():
#         """Swap first two elements"""
#         a[0], a[1] = a[1], a[0]
#         moves.append('X')
#
#     def find_value(val):
#         """Find the index of a value in the array"""
#         for i in range(n):
#             if a[i] == val:
#                 return i
#         return -1
#
#     def is_sorted():
#         """Check if array is sorted"""
#         for i in range(n):
#             if a[i] != i:
#                 return False
#         return True
#
#     # Main algorithm: Place each element 0, 1, 2, ..., n-1 in order
#     # We use a technique where we bring element k to position 0,
#     # then rotate the array so that element k ends up at position k
#
#     for target_val in range(n):
#         # We want to place value 'target_val' at position 'target_val'
#
#         if a[target_val] == target_val:
#             # Already in place
#             continue
#
#         # Find where target_val currently is
#         pos = find_value(target_val)
#
#         # We need to bring target_val to position target_val
#         # Strategy:
#         # 1. Rotate left so that target_val is at position 0 or 1
#         # 2. If at position 1, use X to bring to position 0
#         # 3. Rotate right target_val times
#
#         # But we need to preserve elements 0..target_val-1 at their positions
#         # This requires a more sophisticated approach
#
#         # Alternative approach for n >= 2:
#         # We can always sort by repeatedly:
#         # - Finding the smallest unsorted element
#         # - Bringing it to position 0 using rotations
#         # - Using X swaps and rotations to bubble it to correct position
#
#         pass  # Will implement below
#
#     # Reset and use a different approach
#     a = list(vector)
#     moves = []
#
#     # Bubble sort style using rotations
#     # Key insight: We can reach any permutation from any other using L, R, X
#     # L and R cycle all elements, X swaps first two
#
#     # Strategy: Sort by repeatedly moving the minimum unsorted to its position
#     # Using the fact that with L, R, X we can simulate adjacent swaps
#
#     def rotate_to_bring_to_front(val):
#         """Rotate array until val is at position 0"""
#         while a[0] != val:
#             do_L()
#
#     def rotate_to_bring_to_pos1(val):
#         """Rotate array until val is at position 1"""
#         while a[1] != val:
#             do_L()
#
#     # For each position from 0 to n-2, place the correct element
#     for target_pos in range(n - 1):
#         target_val = target_pos
#
#         if a[target_pos] == target_val:
#             continue
#
#         # Find current position of target_val
#         current_pos = find_value(target_val)
#
#         # Bring target_val to position 0 by rotating
#         # We need to rotate left by current_pos positions
#         for _ in range(current_pos):
#             do_L()
#
#         # Now target_val is at position 0
#         # We need to move it to target_pos
#         # Rotate right target_pos times
#         for _ in range(target_pos):
#             do_R()
#
#         # Now target_val should be at target_pos
#         # But wait, this doesn't work because rotating right moves everything
#
#         # Let's think differently
#         pass
#
#     # Reset again with cleaner approach
#     a = list(vector)
#     moves = []
#
#     # Use bubble sort with adjacent swaps simulated by L, X, R
#     # To swap positions i and i+1:
#     # 1. Rotate left i times (element at i goes to position 0)
#     # 2. X swaps positions 0 and 1
#     # 3. Rotate right i times (everything back, but 0 and 1 swapped)
#
#     def swap_adjacent(i):
#         """Swap elements at positions i and i+1"""
#         # Rotate left i times
#         for _ in range(i):
#             do_L()
#         # Swap first two
#         do_X()
#         # Rotate right i times
#         for _ in range(i):
#             do_R()
#
#     # Bubble sort
#     for i in range(n - 1):
#         for j in range(n - 1 - i):
#             if a[j] > a[j + 1]:
#                 swap_adjacent(j)
#
#     return (moves, a)
#
#
# def main():
#     if len(sys.argv) > 1:
#         try:
#             vector = json.loads(sys.argv[1])
#         except json.JSONDecodeError:
#             vector = [3, 1, 2, 0]
#     else:
#         vector = [3, 1, 2, 0]
#
#     moves, sorted_array = solve(vector)
#
#     result = {
#         "moves": moves,
#         "sorted_array": sorted_array
#     }
#
#     print(json.dumps(result))
#
#
# if __name__ == "__main__":
#     main()
# ============================================================
# Optimizing algorithm using Claude (claude-opus-4-5-20251101)...
# Optimization complete.
#
# Optimized code:
# ============================================================
# import sys
# import json
#
# def solve(vector):
#     """
#     Sorts a vector using only L, R, X moves in polynomial time.
#     Optimized to use at most 0.5·n² + O(n) moves.
#
#     Strategy: Insertion sort from right to left, placing elements n-1, n-2, ..., 0
#     in their correct positions. We chain rotations to minimize total moves.
#     """
#     n = len(vector)
#     if n <= 1:
#         return ([], list(vector))
#
#     # Work on a copy
#     a = list(vector)
#     moves = []
#
#     def do_L():
#         """Left cyclic shift"""
#         temp = a[0]
#         for i in range(n - 1):
#             a[i] = a[i + 1]
#         a[n - 1] = temp
#         moves.append('L')
#
#     def do_R():
#         """Right cyclic shift"""
#         temp = a[n - 1]
#         for i in range(n - 1, 0, -1):
#             a[i] = a[i - 1]
#         a[0] = temp
#         moves.append('R')
#
#     def do_X():
#         """Swap first two elements"""
#         a[0], a[1] = a[1], a[0]
#         moves.append('X')
#
#     def find_value(val):
#         """Find the index of a value in the array"""
#         for i in range(n):
#             if a[i] == val:
#                 return i
#         return -1
#
#     def rotate_left(k):
#         """Rotate left by k positions"""
#         k = k % n
#         for _ in range(k):
#             do_L()
#
#     def rotate_right(k):
#         """Rotate right by k positions"""
#         k = k % n
#         for _ in range(k):
#             do_R()
#
#     # Track current rotation offset
#     # If offset = k, then logical position i corresponds to physical position (i + k) % n
#     # We'll work in logical positions where we want to achieve a[i] = i
#
#     # Optimized approach: Use insertion sort style, but minimize rotations
#     # by processing elements cleverly.
#
#     # Key insight: To swap logical positions i and j (i < j), we can:
#     # 1. Rotate so position i is at physical 0
#     # 2. Rotate further so position j is at physical 1 (if j = i+1) or use chained swaps
#     # For non-adjacent swaps, we bubble.
#
#     # Better approach: Place each element from largest to smallest
#     # This way, once an element is placed, we don't disturb it.
#
#     # Actually, let's use a refined bubble sort that's more efficient.
#     # For bubble sort: we compare and swap adjacent pairs.
#     # Total swaps needed is the number of inversions, at most n(n-1)/2.
#     # Each adjacent swap at position i costs 2i + 1 moves.
#     #
#     # To optimize: instead of going back to position 0 after each swap,
#     # we can stay rotated and continue comparisons.
#
#     # Efficient bubble sort with rotation chaining:
#     # We'll do passes where we move through the array, swapping as needed,
#     # without rotating back after each swap.
#
#     def bubble_sort_optimized():
#         """
#         Bubble sort with rotation chaining.
#         Each pass: rotate through the array, swapping adjacent elements as needed.
#         Track total rotation and only rotate back at the end of each pass.
#         """
#         for end in range(n - 1, 0, -1):
#             # One pass: move the largest unsorted element to position 'end'
#             current_offset = 0  # How much we've rotated left
#
#             for j in range(end):
#                 # We want to compare logical positions j and j+1
#                 # Currently, logical position j is at physical position (j - current_offset) % n
#                 # We need logical position j at physical position 0
#
#                 needed_rotation = (j - current_offset) % n
#                 rotate_left(needed_rotation)
#                 current_offset = j
#
#                 # Now a[0] is logical position j, a[1] is logical position j+1
#                 if a[0] > a[1]:
#                     do_X()
#
#             # After the pass, rotate back so that logical 0 is at physical 0
#             rotate_right(current_offset)
#
#     # Even more optimized: bidirectional bubble sort (cocktail shaker sort)
#     # This can reduce the number of passes and thus rotations.
#
#     def cocktail_shaker_sort():
#         """
#         Cocktail shaker sort - bidirectional bubble sort.
#         Reduces the number of full rotations needed.
#         """
#         left = 0
#         right = n - 1
#
#         while left < right:
#             # Forward pass: move largest to right
#             new_right = left
#             current_offset = 0
#
#             for j in range(left, right):
#                 needed_rotation = (j - current_offset) % n
#                 rotate_left(needed_rotation)
#                 current_offset = j
#
#                 if a[0] > a[1]:
#                     do_X()
#                     new_right = j
#
#             right = new_right
#
#             if left >= right:
#                 rotate_right(current_offset % n)
#                 break
#
#             # Backward pass: move smallest to left
#             new_left = right
#             # Continue from current position, now go backward
#
#             for j in range(right, left, -1):
#                 # Compare positions j-1 and j
#                 # We need position j-1 at physical 0
#                 needed_rotation = (j - 1 - current_offset) % n
#                 rotate_left(needed_rotation)
#                 current_offset = j - 1
#
#                 if a[0] > a[1]:
#                     do_X()
#                     new_left = j
#
#             left = new_left
#
#             # Rotate back
#             rotate_right(current_offset % n)
#
#     # Let's use a simpler but still efficient approach:
#     # Standard bubble sort but chain rotations within each pass
#
#     def efficient_bubble_sort():
#         """
#         Bubble sort with efficient rotation chaining.
#         Each pass moves through array comparing adjacent pairs.
#         Total moves: sum of inversions * (cost per swap when chained)
#         """
#         for i in range(n - 1):
#             # Pass i: bubble the largest unsorted element to position n-1-i
#             # We'll rotate to position 0, then walk through with L moves, swapping as needed
#
#             # Start at position 0
#             current_pos = 0  # Logical position at physical 0
#
#             for j in range(n - 1 - i):
#                 # Move logical position j to physical position 0
#                 if j > current_pos:
#                     rotate_left(j - current_pos)
#                 elif j < current_pos:
#                     rotate_right(current_pos - j)
#                 current_pos = j
#
#                 # Now logical positions j and j+1 are at physical 0 and 1
#                 if a[0] > a[1]:
#                     do_X()
#
#                 # Move to next position efficiently: one L move
#                 do_L()
#                 current_pos = (current_pos + 1) % n
#
#             # At end of pass, rotate back so logical 0 is at physical 0
#             if current_pos != 0:
#                 rotate_right(current_pos)
#
#     # Simplest efficient version: chain L moves through each pass
#     def simple_efficient_bubble():
#         """
#         Simple bubble sort with L chaining.
#         Each pass: rotate to start, then use L to move through, swap with X as needed.
#         At end of pass, rotate back with R moves.
#         """
#         for pass_num in range(n - 1):
#             # Pass: compare positions 0,1 then 1,2 then 2,3 ... up to n-2,n-1-pass_num
#             # Start: make sure we're at position 0
#
#             comparisons = n - 1 - pass_num
#
#             for j in range(comparisons):
#                 # Compare positions j and j+1
#                 # Currently at physical setup where position j is at index 0
#                 if a[0] > a[1]:
#                     do_X()
#
#                 if j < comparisons - 1:
#                     # Move to next comparison: one L
#                     do_L()
#
#             # After comparisons-1 L moves, we've rotated left by (comparisons-1)
#             # Rotate back: (comparisons-1) R moves
#             for _ in range(comparisons - 1):
#                 do_R()
#
#     # Actually, let's reconsider the cost analysis.
#     # In simple_efficient_bubble:
#     # - Pass i does (n-1-i) comparisons
#     # - At most (n-1-i) X swaps
#     # - (n-2-i) L moves and (n-2-i) R moves
#     # Total L+R per pass: 2(n-2-i)
#     # Total L+R over all passes: 2 * sum_{i=0}^{n-2} (n-2-i) = 2 * sum_{k=0}^{n-2} k = (n-2)(n-1)
#     # Total X: at most n(n-1)/2 (number of inversions)
#     # Total moves: (n-2)(n-1) + n(n-1)/2 = (n-1)(n-2 + n/2) = (n-1)(1.5n - 2) ≈ 1.5n² for large n
#
#     # This is still O(n²) but not 0.5n². Let's think more carefully.
#
#     # Key insight from hints:
#     # "Swapping elements at positions i and i+1 costs 2i+1 moves"
#     # If we do bubble sort counting total adjacent swap costs:
#     # Worst case is reverse permutation: we need n(n-1)/2 adjacent swaps
#     # Positions of swaps vary, but on average position is ~n/2
#     # So average cost per swap is ~n, giving n² total.
#
#     # To achieve 0.5n²:
#     # The number of adjacent transpositions for reverse permutation is n(n-1)/2
#     # If each costs 1 move on average... but X alone is 1 move!
#     #
#     # If we could stay at position 0 and just use X efficiently...
#     # But X only swaps positions 0 and 1.
#
#     # New idea: work in a rotated frame.
#     # If we're rotated by k, then X swaps logical positions k and k+1.
#     # So to do all adjacent swaps: rotate, X, rotate, X, ...
#     # Each rotation step is 1 L, each swap is 1 X.
#
#     # Bubble sort pass without rotating back:
#     # Pass: L X L X L X ... L X (if we swap at every position)
#     # n-1 comparisons, at most n-1 X, and n-2 L moves to traverse
#     # Total for one pass: at most 2n-3 moves if every comparison causes a swap
#
#     # Total for all passes: sum of (at most 2(n-1-i)-1) = roughly n² moves still
#
#     # The issue is we keep rotating back after each pass.
#     #
#     # Better idea: track where we are and don't rotate back unnecessarily.
#
#     def optimized_bubble_v2():
#         """
#         Bubble sort where we track rotation offset and minimize rotation moves.
#         """
#         offset = 0  # logical position 'offset' is at physical position 0
#
#         for pass_num in range(n - 1):
#             end = n - 1 - pass_num  # last position to compare in this pass
#
#             # We need to compare positions 0,1 then 1,2 ... then end-1,end
#             # Currently logical 'offset' is at physical 0
#
#             # Rotate to position 0 if needed
#             if offset != 0:
#                 # Rotate right by offset to bring logical 0 to physical 0
#                 if offset <= n // 2:
#                     rotate_right(offset)
#                 else:
#                     rotate_left(n - offset)
#                 offset = 0
#
#             # Now traverse with L moves
#             for j in range(end):
#                 if a[0] > a[1]:
#                     do_X()
#                 if j < end - 1:
#                     do_L()
#                     offset = (offset + 1) % n
#
#             # offset is now at 'end - 1'
#             # For next pass, we need to start at 0 again
#             # But we can optimize by going backward sometimes
#
#         # Final adjustment
#         if offset != 0:
#             if offset <= n // 2:
#                 rotate_right(offset)
#             else:
#                 rotate_left(n - offset)
#
#     # Run the optimized sort
#     optimized_bubble_v2()
#
#     return (moves, a)
#
#
# def main():
#     if len(sys.argv) > 1:
#         try:
#             vector = json.loads(sys.argv[1])
#         except json.JSONDecodeError:
#             vector = [3, 1, 2, 0]
#     else:
#         vector = [3, 1, 2, 0]
#
#     moves, sorted_array = solve(vector)
#
#     result = {
#         "moves": moves,
#         "sorted_array": sorted_array
#     }
#
#     print(json.dumps(result))
#
#
# if __name__ == "__main__":
#     main()
# ============================================================
#
# Original code length: 5570 chars
# Optimized code length: 11967 chars

# %%
print(optimized_code)
# Out:
# import sys
# import json
#
# def solve(vector):
#     """
#     Sorts a vector using only L, R, X moves in polynomial time.
#     Optimized to use at most 0.5·n² + O(n) moves.
#
#     Strategy: Insertion sort from right to left, placing elements n-1, n-2, ..., 0
#     in their correct positions. We chain rotations to minimize total moves.
#     """
#     n = len(vector)
#     if n <= 1:
#         return ([], list(vector))
#
#     # Work on a copy
#     a = list(vector)
#     moves = []
#
#     def do_L():
#         """Left cyclic shift"""
#         temp = a[0]
#         for i in range(n - 1):
#             a[i] = a[i + 1]
#         a[n - 1] = temp
#         moves.append('L')
#
#     def do_R():
#         """Right cyclic shift"""
#         temp = a[n - 1]
#         for i in range(n - 1, 0, -1):
#             a[i] = a[i - 1]
#         a[0] = temp
#         moves.append('R')
#
#     def do_X():
#         """Swap first two elements"""
#         a[0], a[1] = a[1], a[0]
#         moves.append('X')
#
#     def find_value(val):
#         """Find the index of a value in the array"""
#         for i in range(n):
#             if a[i] == val:
#                 return i
#         return -1
#
#     def rotate_left(k):
#         """Rotate left by k positions"""
#         k = k % n
#         for _ in range(k):
#             do_L()
#
#     def rotate_right(k):
#         """Rotate right by k positions"""
#         k = k % n
#         for _ in range(k):
#             do_R()
#
#     # Track current rotation offset
#     # If offset = k, then logical position i corresponds to physical position (i + k) % n
#     # We'll work in logical positions where we want to achieve a[i] = i
#
#     # Optimized approach: Use insertion sort style, but minimize rotations
#     # by processing elements cleverly.
#
#     # Key insight: To swap logical positions i and j (i < j), we can:
#     # 1. Rotate so position i is at physical 0
#     # 2. Rotate further so position j is at physical 1 (if j = i+1) or use chained swaps
#     # For non-adjacent swaps, we bubble.
#
#     # Better approach: Place each element from largest to smallest
#     # This way, once an element is placed, we don't disturb it.
#
#     # Actually, let's use a refined bubble sort that's more efficient.
#     # For bubble sort: we compare and swap adjacent pairs.
#     # Total swaps needed is the number of inversions, at most n(n-1)/2.
#     # Each adjacent swap at position i costs 2i + 1 moves.
#     #
#     # To optimize: instead of going back to position 0 after each swap,
#     # we can stay rotated and continue comparisons.
#
#     # Efficient bubble sort with rotation chaining:
#     # We'll do passes where we move through the array, swapping as needed,
#     # without rotating back after each swap.
#
#     def bubble_sort_optimized():
#         """
#         Bubble sort with rotation chaining.
#         Each pass: rotate through the array, swapping adjacent elements as needed.
#         Track total rotation and only rotate back at the end of each pass.
#         """
#         for end in range(n - 1, 0, -1):
#             # One pass: move the largest unsorted element to position 'end'
#             current_offset = 0  # How much we've rotated left
#
#             for j in range(end):
#                 # We want to compare logical positions j and j+1
#                 # Currently, logical position j is at physical position (j - current_offset) % n
#                 # We need logical position j at physical position 0
#
#                 needed_rotation = (j - current_offset) % n
#                 rotate_left(needed_rotation)
#                 current_offset = j
#
#                 # Now a[0] is logical position j, a[1] is logical position j+1
#                 if a[0] > a[1]:
#                     do_X()
#
#             # After the pass, rotate back so that logical 0 is at physical 0
#             rotate_right(current_offset)
#
#     # Even more optimized: bidirectional bubble sort (cocktail shaker sort)
#     # This can reduce the number of passes and thus rotations.
#
#     def cocktail_shaker_sort():
#         """
#         Cocktail shaker sort - bidirectional bubble sort.
#         Reduces the number of full rotations needed.
#         """
#         left = 0
#         right = n - 1
#
#         while left < right:
#             # Forward pass: move largest to right
#             new_right = left
#             current_offset = 0
#
#             for j in range(left, right):
#                 needed_rotation = (j - current_offset) % n
#                 rotate_left(needed_rotation)
#                 current_offset = j
#
#                 if a[0] > a[1]:
#                     do_X()
#                     new_right = j
#
#             right = new_right
#
#             if left >= right:
#                 rotate_right(current_offset % n)
#                 break
#
#             # Backward pass: move smallest to left
#             new_left = right
#             # Continue from current position, now go backward
#
#             for j in range(right, left, -1):
#                 # Compare positions j-1 and j
#                 # We need position j-1 at physical 0
#                 needed_rotation = (j - 1 - current_offset) % n
#                 rotate_left(needed_rotation)
#                 current_offset = j - 1
#
#                 if a[0] > a[1]:
#                     do_X()
#                     new_left = j
#
#             left = new_left
#
#             # Rotate back
#             rotate_right(current_offset % n)
#
#     # Let's use a simpler but still efficient approach:
#     # Standard bubble sort but chain rotations within each pass
#
#     def efficient_bubble_sort():
#         """
#         Bubble sort with efficient rotation chaining.
#         Each pass moves through array comparing adjacent pairs.
#         Total moves: sum of inversions * (cost per swap when chained)
#         """
#         for i in range(n - 1):
#             # Pass i: bubble the largest unsorted element to position n-1-i
#             # We'll rotate to position 0, then walk through with L moves, swapping as needed
#
#             # Start at position 0
#             current_pos = 0  # Logical position at physical 0
#
#             for j in range(n - 1 - i):
#                 # Move logical position j to physical position 0
#                 if j > current_pos:
#                     rotate_left(j - current_pos)
#                 elif j < current_pos:
#                     rotate_right(current_pos - j)
#                 current_pos = j
#
#                 # Now logical positions j and j+1 are at physical 0 and 1
#                 if a[0] > a[1]:
#                     do_X()
#
#                 # Move to next position efficiently: one L move
#                 do_L()
#                 current_pos = (current_pos + 1) % n
#
#             # At end of pass, rotate back so logical 0 is at physical 0
#             if current_pos != 0:
#                 rotate_right(current_pos)
#
#     # Simplest efficient version: chain L moves through each pass
#     def simple_efficient_bubble():
#         """
#         Simple bubble sort with L chaining.
#         Each pass: rotate to start, then use L to move through, swap with X as needed.
#         At end of pass, rotate back with R moves.
#         """
#         for pass_num in range(n - 1):
#             # Pass: compare positions 0,1 then 1,2 then 2,3 ... up to n-2,n-1-pass_num
#             # Start: make sure we're at position 0
#
#             comparisons = n - 1 - pass_num
#
#             for j in range(comparisons):
#                 # Compare positions j and j+1
#                 # Currently at physical setup where position j is at index 0
#                 if a[0] > a[1]:
#                     do_X()
#
#                 if j < comparisons - 1:
#                     # Move to next comparison: one L
#                     do_L()
#
#             # After comparisons-1 L moves, we've rotated left by (comparisons-1)
#             # Rotate back: (comparisons-1) R moves
#             for _ in range(comparisons - 1):
#                 do_R()
#
#     # Actually, let's reconsider the cost analysis.
#     # In simple_efficient_bubble:
#     # - Pass i does (n-1-i) comparisons
#     # - At most (n-1-i) X swaps
#     # - (n-2-i) L moves and (n-2-i) R moves
#     # Total L+R per pass: 2(n-2-i)
#     # Total L+R over all passes: 2 * sum_{i=0}^{n-2} (n-2-i) = 2 * sum_{k=0}^{n-2} k = (n-2)(n-1)
#     # Total X: at most n(n-1)/2 (number of inversions)
#     # Total moves: (n-2)(n-1) + n(n-1)/2 = (n-1)(n-2 + n/2) = (n-1)(1.5n - 2) ≈ 1.5n² for large n
#
#     # This is still O(n²) but not 0.5n². Let's think more carefully.
#
#     # Key insight from hints:
#     # "Swapping elements at positions i and i+1 costs 2i+1 moves"
#     # If we do bubble sort counting total adjacent swap costs:
#     # Worst case is reverse permutation: we need n(n-1)/2 adjacent swaps
#     # Positions of swaps vary, but on average position is ~n/2
#     # So average cost per swap is ~n, giving n² total.
#
#     # To achieve 0.5n²:
#     # The number of adjacent transpositions for reverse permutation is n(n-1)/2
#     # If each costs 1 move on average... but X alone is 1 move!
#     #
#     # If we could stay at position 0 and just use X efficiently...
#     # But X only swaps positions 0 and 1.
#
#     # New idea: work in a rotated frame.
#     # If we're rotated by k, then X swaps logical positions k and k+1.
#     # So to do all adjacent swaps: rotate, X, rotate, X, ...
#     # Each rotation step is 1 L, each swap is 1 X.
#
#     # Bubble sort pass without rotating back:
#     # Pass: L X L X L X ... L X (if we swap at every position)
#     # n-1 comparisons, at most n-1 X, and n-2 L moves to traverse
#     # Total for one pass: at most 2n-3 moves if every comparison causes a swap
#
#     # Total for all passes: sum of (at most 2(n-1-i)-1) = roughly n² moves still
#
#     # The issue is we keep rotating back after each pass.
#     #
#     # Better idea: track where we are and don't rotate back unnecessarily.
#
#     def optimized_bubble_v2():
#         """
#         Bubble sort where we track rotation offset and minimize rotation moves.
#         """
#         offset = 0  # logical position 'offset' is at physical position 0
#
#         for pass_num in range(n - 1):
#             end = n - 1 - pass_num  # last position to compare in this pass
#
#             # We need to compare positions 0,1 then 1,2 ... then end-1,end
#             # Currently logical 'offset' is at physical 0
#
#             # Rotate to position 0 if needed
#             if offset != 0:
#                 # Rotate right by offset to bring logical 0 to physical 0
#                 if offset <= n // 2:
#                     rotate_right(offset)
#                 else:
#                     rotate_left(n - offset)
#                 offset = 0
#
#             # Now traverse with L moves
#             for j in range(end):
#                 if a[0] > a[1]:
#                     do_X()
#                 if j < end - 1:
#                     do_L()
#                     offset = (offset + 1) % n
#
#             # offset is now at 'end - 1'
#             # For next pass, we need to start at 0 again
#             # But we can optimize by going backward sometimes
#
#         # Final adjustment
#         if offset != 0:
#             if offset <= n // 2:
#                 rotate_right(offset)
#             else:
#                 rotate_left(n - offset)
#
#     # Run the optimized sort
#     optimized_bubble_v2()
#
#     return (moves, a)
#
#
# def main():
#     if len(sys.argv) > 1:
#         try:
#             vector = json.loads(sys.argv[1])
#         except json.JSONDecodeError:
#             vector = [3, 1, 2, 0]
#     else:
#         vector = [3, 1, 2, 0]
#
#     moves, sorted_array = solve(vector)
#
#     result = {
#         "moves": moves,
#         "sorted_array": sorted_array
#     }
#
#     print(json.dumps(result))
#
#
# if __name__ == "__main__":
#     main()

# %%
# Test on a specific permutation
if solver and solver.generated_code:
    test_perm = np.array([1, 2, 3, 0])
    print(f"Testing permutation: {test_perm}")
    
    result = solver.solve(test_perm)
    
    if result['success']:
        print(f"Success!")
        print(f"Moves: {result['moves']}")
        print(f"Number of moves: {len(result['moves'])}")
        print(f"Sorted array: {result['sorted_array']}")
        print(f"Verification: {result['verification']['is_correct']}")
    else:
        print(f"Failed: {result.get('error', 'Unknown error')}")
# Out:
# Testing permutation: [1 2 3 0]
# Success!
# Moves: ['L', 'L', 'X', 'R', 'R', 'L', 'X', 'R', 'X']
# Number of moves: 9
# Sorted array: [0, 1, 2, 3]
# Verification: True

# %%
# Run multiple random tests
if solver and solver.generated_code:
    print("Running 10 random tests...")
    results = solver.test_random(n=4, num_tests=10)
    
    print(f"\nFinal Results:")
    print(f"Success rate: {results['success_rate']*100:.1f}%")
    print(f"Passed: {results['success_count']}/{results['num_tests']}")
# Out:
# Running 10 random tests...
# Test 1/10: [3, 0, 1, 2]
#   ✓ Solved with 9 moves
# Test 2/10: [1, 3, 2, 0]
#   ✓ Solved with 10 moves
# Test 3/10: [2, 1, 3, 0]
#   ✓ Solved with 10 moves
# Test 4/10: [0, 2, 1, 3]
#   ✓ Solved with 7 moves
# Test 5/10: [2, 1, 0, 3]
#   ✓ Solved with 9 moves
# Test 6/10: [3, 0, 1, 2]
#   ✓ Solved with 9 moves
# Test 7/10: [1, 2, 0, 3]
#   ✓ Solved with 8 moves
# Test 8/10: [1, 2, 0, 3]
#   ✓ Solved with 8 moves
# Test 9/10: [0, 3, 1, 2]
#   ✓ Solved with 8 moves
# Test 10/10: [2, 3, 1, 0]
#   ✓ Solved with 11 moves
#
# Final Results:
# Success rate: 100.0%
# Passed: 10/10

# %% [markdown]
# ## 6. Manual Code Execution and Verification
#
# You can also manually test code snippets.

# %%
from main import execute_generated_code

# Example: A simple (but inefficient) sorting algorithm
sample_code = '''
import sys
import json


def apply_L(a):
    n = len(a)
    first = a[0]
    for i in range(n - 1):
        a[i] = a[i + 1]
    a[n - 1] = first


def apply_R(a):
    n = len(a)
    last = a[n - 1]
    for i in range(n - 1, 0, -1):
        a[i] = a[i - 1]
    a[0] = last


def apply_X(a):
    a[0], a[1] = a[1], a[0]


def swap_adjacent(a, pos, moves):
    for _ in range(pos):
        apply_L(a)
        moves.append('L')
    
    apply_X(a)
    moves.append('X')
    
    for _ in range(pos):
        apply_R(a)
        moves.append('R')


def solve(vector):

    a = list(vector)
    moves = []
    n = len(a)
    
    # Handle trivial cases
    if n <= 1:
        return moves, a
    
    # Bubble sort: O(n^2) passes
    # In each pass, bubble the largest unsorted element to its correct position
    for i in range(n - 1):
        swapped = False
        for j in range(n - 1 - i):
            if a[j] > a[j + 1]:
                swap_adjacent(a, j, moves)
                swapped = True
        # Early termination if no swaps occurred (array is sorted)
        if not swapped:
            break
    
    return moves, a

if __name__ == "__main__":
    if len(sys.argv) > 1:
        vector = json.loads(sys.argv[1])
    else:
        vector = [3, 1, 2]
    
    moves, sorted_array = solve(vector)
    print(json.dumps({"moves": moves, "sorted_array": sorted_array}))

'''

# Test the sample code
test_vector = [1,2,3,4,5,6,8,7,0]
result = execute_generated_code(sample_code, test_vector)

print(f"Input: {test_vector}")
if result['success']:
    print(f"Output: {result['sorted_array']}")
    print(f"Moves ({len(result['moves'])}): {result['moves']}")
    print
else:
    print(f"Error: {result.get('error', 'Unknown')}")
# Out:
# Input: [1, 2, 3, 4, 5, 6, 8, 7, 0]
# Output: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Moves (77): ['L', 'L', 'L', 'L', 'L', 'L', 'X', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'X', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'L', 'X', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'L', 'L', 'X', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'L', 'X', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'X', 'R', 'R', 'R', 'L', 'L', 'X', 'R', 'R', 'L', 'X', 'R', 'X']

# %%
# Verify the solution manually
if result['success']:
    original = np.array(test_vector)
    expected = np.arange(len(test_vector))
    
    verification = verify_solution(original, result['moves'], expected)
    print(f"Verification result: {verification['is_correct']}")
    print(f"Original: {verification['original']}")
    print(f"Result: {verification['result']}")
    print(f"Expected: {verification['expected']}")
# Out:
# Verification result: True
# Original: [1, 2, 3, 4, 5, 6, 8, 7, 0]
# Result: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Expected: [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ## 7. Compare Different Providers
#
# Test the same permutation with different LLM providers.

# %%
def compare_providers(providers: list, permutation: np.ndarray):
    """Compare solutions from different LLM providers."""
    results = {}
    
    for provider in providers:
        print(f"\n{'='*60}")
        print(f"Testing {provider.upper()}")
        print(f"{'='*60}")
        
        try:
            client = get_llm_client(provider)
            solver = PermutationSolver(client, PermutationConfig(length=len(permutation)))
            solver.generate_algorithm(len(permutation))
            result = solver.solve(permutation)
            
            results[provider] = {
                'success': result['success'],
                'num_moves': len(result.get('moves', [])) if result['success'] else None,
                'is_correct': result.get('verification', {}).get('is_correct', False)
            }
            
            if result['success']:
                print(f"✓ Success with {len(result['moves'])} moves")
            else:
                print(f"✗ Failed: {result.get('error', 'Unknown')}")
                
        except Exception as e:
            results[provider] = {'error': str(e)}
            print(f"✗ Error: {e}")
    
    return results

# Uncomment to run comparison (requires API keys for all providers)
test_perm = np.array([1, 2, 3, 0])
comparison = compare_providers(['openai', 'gemini', 'claude'], test_perm)
print("\nComparison Results:")
print(json.dumps(comparison, indent=2))

# %% [markdown]
# ## 8. Save Generated Code for Later Use

# %%
from main import save_code_to_file

# If you have generated code, save it
if solver and solver.generated_code:
    filepath = save_code_to_file(solver.generated_code, 'generated_solver.py')
    print(f"Code saved to: {filepath}")
